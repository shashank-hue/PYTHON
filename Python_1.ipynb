# %% [markdown]
# <a href="https://colab.research.google.com/github/shashank-hue/PYTHON/blob/main/Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(7):
    print(i,end=" ")
# Out:
# 0 1 2 3 4 5 6

# %%
for i in 10, 20, 40:
    print("hi")
# Out:
# hi
# hi
# hi

# %%
for i in 10, 20, 40:
  print(i)
# Out:
# 10
# 20
# 40

# %%
for i in range(2,10,2):
  print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
for i in range(100,1,-5):
  print(i)
# Out:
# 100
# 95
# 90
# 85
# 80
# 75
# 70
# 65
# 60
# 55
# 50
# 45
# 40
# 35
# 30
# 25
# 20
# 15
# 10
# 5

# %%
x=10
for i in range(20, 10, -2):
  x = x+2
  print("Hi")
for i in "Hi":
  print(x,end=" ")
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# 20 20

# %%
z=3
for i in "island":
  z=z+1
s=z
for i in range(z):
  s=s+i
print(s)
# Out:
# 45

# %%
for i in range(5):
    print("*",end=" ")
print()
for j in range(10):
  print("*       *")
for k in range(5):
    print("*",end=" ")
print()
# Out:
# * * * * *
# *       *
# *       *
# *       *
# *       *
# *       *
# *       *
# *       *
# *       *
# *       *
# *       *
# * * * * *

# %%
a = int(input("Enter the num: "))
if a % 2==0:
  for i in range(1,11):
   print("{} x {} = {}".format(i,a,i*a))
else:
  for i in range(1,a+1):
     print("{} x {} = {}".format(i,a,i*a))
# Out:
# Enter the num: 12
# 1 x 12 = 12
# 2 x 12 = 24
# 3 x 12 = 36
# 4 x 12 = 48
# 5 x 12 = 60
# 6 x 12 = 72
# 7 x 12 = 84
# 8 x 12 = 96
# 9 x 12 = 108
# 10 x 12 = 120

# %%
a =input("Enter any sentence: ")
c = 0
for i in a:
  if  i == " ":
    c=c+1
print("The total words:",c+1)
# Out:
# Enter any sentence:
# The total words: 12

# %%
a = input("Enter any sentance:")
c = 0
for i in range(len(a)):
  if a[i]==" " and a[i+1]!=" ":
    c=c+1
print("The total words:",c+1)
# Out:
# Enter any sentance:i in h
# The total words: 3

# %%
import random
p1 = input("Enter player1: ")
p2 = input("Enter player2: ")
s1 = 10
s2 = 10
d1 = random.randint(1, 10)
d2 = random.randint(1, 10)
print("_____PLAYER1 TURN_____")
while(True):
  g1 = int(input("Enter ur guess: "))
  s1 = s1-1
  if g1==d1:
    break
print("_____PLAYER2 TURN_____")
while(True):
  g2 = int(input("Enter ur guess: "))
  s2 = s2-1
  if g2==d2:
    print("_____SUMMARY_____")
    print("{}:{}".formt(p1,s1))
    print("{}:{}".format(p2,s2))
    print("__________________________")
if s1==s2:
  print("Winner is ",p1)
elif s1>s2:
    print("Winner is ",p2)
  else:
    print("DRAW")
# Out:
#   File "/tmp/ipykernel_2659/1907485925.py", line 25
#     elif s1>s2:
#     ^
# SyntaxError: invalid syntax
